# %% [markdown]
# # Deploying a Live Intraday Trading Agent
#
# For the purposes of our example in this notebook will be trading on a 5-minute timeframe. Oanda is used as the trading platform for this exercise, which allows us to place trades in Python using a paper trading account. This allows us to achieve a realistic trading environment for our exercise. Deploying a live trading bot is achieved simply by changing the API credentials.

# %%
# %matplotlib widget
import os
import numpy as np
import pandas as pd
from pylab import plt
from pprint import pprint
plt.style.use('seaborn-v0_8')
pd.set_option('mode.chained_assignment', None)
pd.set_option ('display.float_format', '{:.5f}'. format)
np.set_printoptions(suppress=True, precision=4)
os.environ['PYTHONHASHSEED'] = '0'

# Select Keras backend
import os
# os.environ['KERAS_BACKEND'] = 'jax'
os.environ['KERAS_BACKEND'] = 'tensorflow'

# %% [markdown]
# # The Oanada API

# %%
import tpqoa
api = tpqoa.tpqoa('../oanda.cfg')
ins = api.get_instruments()
print([instrument[0] for instrument in ins])
# Out:
# ['AUD/CAD', 'AUD/CHF', 'AUD/HKD', 'AUD/JPY', 'AUD/NZD', 'AUD/SGD', 'AUD/USD', 'Australia 200', 'Brent Crude Oil', 'Bund', 'CAD/CHF', 'CAD/HKD', 'CAD/JPY', 'CAD/SGD', 'CHF/HKD', 'CHF/JPY', 'CHF/ZAR', 'China A50', 'China H Shares', 'Copper', 'Corn', 'EUR/AUD', 'EUR/CAD', 'EUR/CHF', 'EUR/CZK', 'EUR/DKK', 'EUR/GBP', 'EUR/HKD', 'EUR/HUF', 'EUR/JPY', 'EUR/NOK', 'EUR/NZD', 'EUR/PLN', 'EUR/SEK', 'EUR/SGD', 'EUR/TRY', 'EUR/USD', 'EUR/ZAR', 'Europe 50', 'France 40', 'GBP/AUD', 'GBP/CAD', 'GBP/CHF', 'GBP/HKD', 'GBP/JPY', 'GBP/NZD', 'GBP/PLN', 'GBP/SGD', 'GBP/USD', 'GBP/ZAR', 'Germany 30', 'Gold', 'Gold/AUD', 'Gold/CAD', 'Gold/CHF', 'Gold/EUR', 'Gold/GBP', 'Gold/HKD', 'Gold/JPY', 'Gold/NZD', 'Gold/SGD', 'Gold/Silver', 'HKD/JPY', 'Hong Kong 33', 'Japan 225', 'Japan 225 (JPY)', 'NZD/CAD', 'NZD/CHF', 'NZD/HKD', 'NZD/JPY', 'NZD/SGD', 'NZD/USD', 'Natural Gas', 'Netherlands 25', 'Palladium', 'Platinum', 'SGD/CHF', 'SGD/JPY', 'Silver', 'Silver/AUD', 'Silver/CAD', 'Silver/CHF', 'Silver/EUR', 'Silver/GBP', 'Silver/HKD', 'Silver/JPY', 'Silver/NZD', 'Silver/SGD', 'Singapore 30', 'Soybeans', 'Spain 35', 'Sugar', 'Switzerland 20', 'TRY/JPY', 'UK 100', 'UK 10Y Gilt', 'US 10Y T-Note', 'US 2Y T-Note', 'US 5Y T-Note', 'US Nas 100', 'US Russ 2000', 'US SPX 500', 'US T-Bond', 'US Wall St 30', 'USD/CAD', 'USD/CHF', 'USD/CNH', 'USD/CZK', 'USD/DKK', 'USD/HKD', 'USD/HUF', 'USD/JPY', 'USD/MXN', 'USD/NOK', 'USD/PLN', 'USD/SEK', 'USD/SGD', 'USD/THB', 'USD/TRY', 'USD/ZAR', 'West Texas Oil', 'Wheat', 'ZAR/JPY']

# %%
# Gather 1-minute OHCLV data from 2020

raw_data = api.get_history(instrument='EUR_USD', start='2020-02-01', end='2020-02-29', granularity='M1', price='M')
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27652 entries, 2020-02-02 22:00:00 to 2020-02-28 21:59:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   o         27652 non-null  float64
#  1   h         27652 non-null  float64
#  2   l         27652 non-null  float64
#  3   c         27652 non-null  float64
#  4   volume    27652 non-null  int64
#  5   complete  27652 non-null  bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 1.3 MB

# %%
raw_data.head()
# Out:
#                           o       h       l       c  volume  complete
# time
# 2020-02-02 22:00:00 1.10956 1.10956 1.10951 1.10951       3      True
# 2020-02-02 22:01:00 1.10948 1.10948 1.10940 1.10940       3      True
# 2020-02-02 22:02:00 1.10940 1.10940 1.10939 1.10939       2      True
# 2020-02-02 22:03:00 1.10934 1.10934 1.10930 1.10930       2      True
# 2020-02-02 22:06:00 1.10928 1.10931 1.10928 1.10931       2      True

# %%
raw_data['c'].plot(figsize=(10, 6));
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Data can be streamed from the Oanda platform. This is useful for deployment.

# %%
api.stream_data('EUR_USD', stop=10)
# Out:
# 2024-07-05T14:33:31.830277191Z 1.08242 1.0825
# 2024-07-05T14:33:34.817613159Z 1.08241 1.08249
# 2024-07-05T14:33:35.672190484Z 1.08241 1.0825
# 2024-07-05T14:33:36.063062119Z 1.08241 1.08248
# 2024-07-05T14:33:36.116483016Z 1.08241 1.0825
# 2024-07-05T14:33:36.413145679Z 1.08242 1.08249
# 2024-07-05T14:33:36.964903180Z 1.08241 1.0825
# 2024-07-05T14:33:38.109412643Z 1.08242 1.0825
# 2024-07-05T14:33:38.556814127Z 1.08244 1.08251
# 2024-07-05T14:33:38.729233472Z 1.08243 1.08251

# %% [markdown]
# We can create (and close) orders using the Oanda API.

# %%
def print_details(order):
  # Reduce the amount of information printed
  return order['time'], order['instrument'], order['units'], order['price'], order['pl']

# %%
order = api.create_order('EUR_USD', units=25000, suppress=True, ret=True)
pprint(order)

print_details(order)
# Out:
# {'accountBalance': '100553.7585',
#  'accountID': '101-004-28878656-001',
#  'batchID': '2444',
#  'commission': '0.0',
#  'financing': '0.0',
#  'fullPrice': {'asks': [{'liquidity': '475000', 'price': 1.08161},
#                         {'liquidity': '500000', 'price': 1.08162},
#                         {'liquidity': '2000000', 'price': 1.08163},
#                         {'liquidity': '2000000', 'price': 1.08164},
#                         {'liquidity': '5000000', 'price': 1.08165}],
#                'bids': [{'liquidity': '500000', 'price': 1.08154},
#                         {'liquidity': '2500000', 'price': 1.08153},
#                         {'liquidity': '2000000', 'price': 1.08152},
#                         {'liquidity': '5000000', 'price': 1.08151}],
#                'closeoutAsk': 1.08183,
#                'closeoutBid': 1.08132,
#                'type': 'PRICE'},
#  'fullVWAP': 1.08161,
#  'gainQuoteHomeConversionFactor': '0.777784296173',
#  'guaranteedExecutionFee': '0.0',
#  'halfSpreadCost': '0.684',
#  'id': '2445',
#  'instrument': 'EUR_USD',
#  'lossQuoteHomeConversionFactor': '0.785601223773',
#  'orderID': '2444',
#  'pl': '-167.1367',
#  'price': 1.08161,
#  'reason': 'MARKET_ORDER',
#  'requestID': '79272589760921341',
#  'time': '2024-07-05T14:17:08.551671504Z',
#  'tradesClosed': [{'financing': '0.0',
#                    'guaranteedExecutionFee': '0.0',
#                    'halfSpreadCost': '0.684',
#                    'price': 1.08161,
#                    'realizedPL': '-167.1367',
#                    'tradeID': '2435',
#                    'units': '25000.0'}],
#  'type': 'ORDER_FILL',
#  'units': '25000.0',
#  'userID': 28878656}
# ('2024-07-05T14:17:08.551671504Z', 'EUR_USD', '25000.0', 1.08161, '-167.1367')

# %% [markdown]
# To close the position we simply reverse the sign on our order.

# %%
order = api.create_order('EUR_USD', units=-25000, suppress=True, ret=True)
print_details(order)
# Out:
# ('2024-07-05T14:17:11.477740931Z', 'EUR_USD', '-25000.0', 1.08155, '0.0')

# %% [markdown]
# We can also submit orders with stop losses, or trailing stop losses.

# %%
sl_order = api.create_order('EUR_USD', units=25000, sl_distance=0.005, suppress=True, ret=True)
print_details(sl_order)
# Out:
# ('2024-07-05T14:17:34.411647452Z', 'EUR_USD', '25000.0', 1.08145, '0.0')

# %%
tsl_order = api.create_order('EUR_USD', units=25000, tsl_distance=0.005, suppress=True, ret=True)
print_details(tsl_order)
# Out:
# ('2024-07-05T14:17:38.480116481Z', 'EUR_USD', '25000.0', 1.08141, '0.0')

# %% [markdown]
# Order with a take profit target:

# %%
tp_order = api.create_order('EUR_USD', units=25000, tp_price=order['price'] + 0.001, suppress=True, ret=True)
print(tp_order['time'], tp_order['instrument'], tp_order['units'])
# Out:
# 2024-07-05T14:20:28.432055399Z EUR_USD 25000.0

# %% [markdown]
# Print a summary of recent transactions:

# %%
api.print_transactions(tid=int(order['id'])-22)
# Out:
#  388 | 2024-06-19T07:50:35.47 | EUR_USD |  50000.0 |  -0.9871
#  390 | 2024-06-19T07:50:40.81 | EUR_USD | -50000.0 |  -1.3819
#  392 | 2024-06-19T07:50:46.25 | EUR_USD |  50000.0 |  -1.5793
#  394 | 2024-06-19T07:51:06.46 | EUR_USD | -50000.0 |  -0.3948
#  396 | 2024-06-19T07:51:46.15 | EUR_USD |  25000.0 |  -1.1845
#  398 | 2024-06-19T18:46:44.62 | EUR_USD | -25000.0 |      0.0
#  400 | 2024-06-19T18:52:01.07 | EUR_USD |  50000.0 |  -0.3952
#  402 | 2024-06-19T18:52:06.35 | EUR_USD | -50000.0 |  -1.1856
#  405 | 2024-06-20T09:14:07.84 | EUR_USD |  25000.0 |  39.7585
#  407 | 2024-06-20T11:09:21.93 | EUR_USD |  25000.0 |      0.0
#  409 | 2024-06-20T11:09:22.23 | EUR_USD | -25000.0 |  -1.5835
#  411 | 2024-06-20T11:09:22.50 | EUR_USD |  25000.0 |      0.0
#  414 | 2024-06-20T11:09:22.63 | EUR_USD |  25000.0 |      0.0

# %%
api.get_account_summary()
# Out:
# {'id': '101-004-28878656-001',
#  'alias': 'Primary',
#  'currency': 'GBP',
#  'balance': '99772.3496',
#  'createdByUserID': 28878656,
#  'createdTime': '2024-04-13T13:34:43.181204491Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-228.0246',
#  'resettablePL': '-228.0246',
#  'resettablePLTime': '0',
#  'financing': '0.3742',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.03333333333333',
#  'openTradeCount': 2,
#  'openPositionCount': 1,
#  'pendingOrderCount': 2,
#  'hedgingEnabled': False,
#  'unrealizedPL': '-2.3752',
#  'NAV': '99769.9744',
#  'marginUsed': '1409.1167',
#  'marginAvailable': '98360.8693',
#  'positionValue': '42273.5',
#  'marginCloseoutUnrealizedPL': '-1.1817',
#  'marginCloseoutNAV': '99771.1679',
#  'marginCloseoutMarginUsed': '1409.1167',
#  'marginCloseoutPercent': '0.00706',
#  'marginCloseoutPositionValue': '42273.5',
#  'withdrawalLimit': '98360.8693',
#  'marginCallMarginUsed': '1409.1167',
#  'marginCallPercent': '0.01412',
#  'lastTransactionID': '416'}

# %%
# Close out all open positions
# order = api.create_order('EUR_USD', units=-25000, suppress=True, ret=True)
# print_details(order)

# %% [markdown]
# # Data Preparation
#
# We use a OpenAI gym-like environment that is integrated with the Oanda API, with the class is defined in `oandaenv.py`.

# %%
import sys
sys.path.insert(0, './5. Deep Reinforcement Learning')

import oandaenv as oe
import importlib
importlib.reload(oe)
# Out:
# <module 'oandaenv' from '/Users/dev/QuantConcepts/5. Deep Reinforcement Learning/oandaenv.py'>

# %% [markdown]
# In the following steps we download EUR_USD timeseries data which will form our train/validate/test split.

# %%
symbol = 'EUR_USD'
start_datetime = '2024-05-01 05:00:00'
learn_val_split = '2024-05-15 05:00:00'
val_test_split = '2024-05-22 05:00:00'
end_datetime = '2024-05-29 05:00:00'
lags = 6
granularity='M5'

# %%
# %time
learn_env = oe.OandaEnv(
    symbol=symbol,
    start=start_datetime,
    end=learn_val_split,
    granularity=granularity,
    price='M',
    features=[symbol, 'r', 's', 'm', 'v'],
    window=10,
    lags=lags,
    leverage=20,
    min_accuracy=0.4,
    min_performance=0.8
  )

learn_env.data.info()
# Out:
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 12.9 µs
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2869 entries, 2024-05-01 05:50:00 to 2024-05-15 04:55:00
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   EUR_USD  2869 non-null   float64
#  1   r        2869 non-null   float64
#  2   s        2869 non-null   float64
#  3   m        2869 non-null   float64
#  4   v        2869 non-null   float64
#  5   d        2869 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 156.9 KB

# %%
learn_env.data.head(), learn_env.data.tail()
# Out:
# (                     EUR_USD        r       s        m       v  d
#  time
#  2024-05-01 05:50:00  1.06560  0.00006 1.06556  0.00000 0.00007  1
#  2024-05-01 05:55:00  1.06556 -0.00004 1.06555 -0.00001 0.00007  0
#  2024-05-01 06:00:00  1.06550 -0.00006 1.06554 -0.00001 0.00007  0
#  2024-05-01 06:05:00  1.06554  0.00004 1.06554 -0.00001 0.00007  1
#  2024-05-01 06:10:00  1.06555  0.00001 1.06554  0.00000 0.00007  1,
#                       EUR_USD        r       s        m       v  d
#  time
#  2024-05-15 04:35:00  1.08216 -0.00010 1.08243 -0.00004 0.00005  0
#  2024-05-15 04:40:00  1.08220  0.00004 1.08238 -0.00004 0.00005  1
#  2024-05-15 04:45:00  1.08217 -0.00003 1.08234 -0.00004 0.00005  0
#  2024-05-15 04:50:00  1.08210 -0.00006 1.08230 -0.00004 0.00004  0
#  2024-05-15 04:55:00  1.08216  0.00006 1.08227 -0.00003 0.00005  1)

# %%
# %time
valid_env = oe.OandaEnv(
    symbol=learn_env.symbol,
    start=learn_val_split,
    end=val_test_split,
    granularity=learn_env.granularity,
    price=learn_env.price,
    features=learn_env.features,
    window=learn_env.window,
    lags=learn_env.lags,
    leverage=learn_env.leverage,
    min_accuracy=learn_env.min_accuracy,
    min_performance=learn_env.min_performance,
    mu=learn_env.mu,
    std=learn_env.std
  )

valid_env.data.info()
# Out:
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 14.1 µs
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1395 entries, 2024-05-15 05:50:00 to 2024-05-22 04:55:00
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   EUR_USD  1395 non-null   float64
#  1   r        1395 non-null   float64
#  2   s        1395 non-null   float64
#  3   m        1395 non-null   float64
#  4   v        1395 non-null   float64
#  5   d        1395 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 76.3 KB

# %%
valid_env.data.head(), valid_env.data.tail()
# Out:
# (                     EUR_USD        r       s       m       v  d
#  time
#  2024-05-15 05:50:00  1.08253  0.00011 1.08235 0.00003 0.00007  1
#  2024-05-15 05:55:00  1.08271  0.00017 1.08240 0.00004 0.00009  1
#  2024-05-15 06:00:00  1.08281  0.00009 1.08244 0.00004 0.00008  1
#  2024-05-15 06:05:00  1.08266 -0.00014 1.08247 0.00003 0.00010  0
#  2024-05-15 06:10:00  1.08258 -0.00007 1.08249 0.00002 0.00010  0,
#                       EUR_USD        r       s        m       v  d
#  time
#  2024-05-22 04:35:00  1.08533 -0.00010 1.08544 -0.00001 0.00007  0
#  2024-05-22 04:40:00  1.08533  0.00000 1.08543 -0.00001 0.00007  0
#  2024-05-22 04:45:00  1.08536  0.00003 1.08541 -0.00002 0.00006  1
#  2024-05-22 04:50:00  1.08542  0.00006 1.08539 -0.00001 0.00006  1
#  2024-05-22 04:55:00  1.08536 -0.00006 1.08539 -0.00001 0.00006  0)

# %%
# %time
test_env = oe.OandaEnv(
    symbol=learn_env.symbol,
    start=val_test_split,
    end=end_datetime,
    granularity=learn_env.granularity,
    price=learn_env.price,
    features=learn_env.features,
    window=learn_env.window,
    lags=learn_env.lags,
    leverage=learn_env.leverage,
    min_accuracy=learn_env.min_accuracy,
    min_performance=learn_env.min_performance,
    mu=learn_env.mu,
    std=learn_env.std
  )

test_env.data.info()
# Out:
# CPU times: user 3 µs, sys: 4 µs, total: 7 µs
# Wall time: 12.2 µs
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1430 entries, 2024-05-22 05:50:00 to 2024-05-29 04:55:00
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   EUR_USD  1430 non-null   float64
#  1   r        1430 non-null   float64
#  2   s        1430 non-null   float64
#  3   m        1430 non-null   float64
#  4   v        1430 non-null   float64
#  5   d        1430 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 78.2 KB

# %%
test_env.data.head(), test_env.data.tail()
# Out:
# (                     EUR_USD        r       s       m       v  d
#  time
#  2024-05-22 05:50:00  1.08560  0.00002 1.08545 0.00002 0.00006  1
#  2024-05-22 05:55:00  1.08560  0.00000 1.08548 0.00003 0.00005  0
#  2024-05-22 06:00:00  1.08574  0.00013 1.08553 0.00005 0.00005  1
#  2024-05-22 06:05:00  1.08568 -0.00006 1.08557 0.00004 0.00006  0
#  2024-05-22 06:10:00  1.08568  0.00000 1.08560 0.00003 0.00006  0,
#                       EUR_USD        r       s        m       v  d
#  time
#  2024-05-29 04:35:00  1.08462  0.00006 1.08458 -0.00001 0.00007  1
#  2024-05-29 04:40:00  1.08468  0.00006 1.08456 -0.00001 0.00007  1
#  2024-05-29 04:45:00  1.08465 -0.00003 1.08456 -0.00001 0.00007  0
#  2024-05-29 04:50:00  1.08467  0.00002 1.08457  0.00001 0.00005  1
#  2024-05-29 04:55:00  1.08478  0.00010 1.08460  0.00003 0.00005  1)

# %% [markdown]
# Let us now visualize our training, validation and testing datasets.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.clf()
ax = learn_env.data[learn_env.symbol].plot(figsize=(10, 6))
plt.axvline(learn_env.data.index[-1], ls='--')
valid_env.data[learn_env.symbol].plot(ax=ax, style='-.')
plt.axvline(valid_env.data.index[-1], ls='--')
test_env.data[learn_env.symbol].plot(ax=ax, style='--')
# plt.show()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Trading Agent
#
# ## Simplifying Assumptions
#
# To simplify the problem on this initial pass, and make the problem tractable in a single Jupyter notebook, some simplifying assumptions are made:
# * **Transaction costs:** The effect of transaction costs are ignored in the following exercise. On short time-frames like 5 minutes, the transaction costs are rarely negligible so this would have a sizable effect on any profit derived from this strategy. To avoid that problem, one would have to consider longer timescales (assuming transaction costs are held fixed).
# * **Risk management:** We will not use stop-loss trades or trailing-stop-loss trades, which could be useful to experiment with.
#
# ## Features
#
# As can be seen in the `_prepare_data` method in `oandaenv.py`, a few features are used as input to our model. These are:
# - `r`: the return of the bar.
# - `s`: the rolling average of the price over the time window.
# - `m`: the rolling average of the returns over the time window.
# - `v`: the volatility of the returns over the time window.
# - `d`: the direction of the move (0=down, 1=up).
#
# All of these features are provided for each bar, and the 6 previous 'lags'/bars are used to predict the direction of the subsequent timestep.
#
# More features could certainly be added to improve the performance of the model. This is in no way an attempt to create an optimal/performant trading agent.
#
# Some features that come to mind as potentially valuable are:
# - Time information (such as hour of day, minute of hour), to capture any seasonality that may exist in the returns.
# - Common trading indicators (such as RSI, Z-Score).
# - Features based factors outside of historical price information, e.g. sentiment analysis.
#
# The cell below introduces the `Agent` class that implements the DQN reinforcement learning agent used for this exercise.

# %%
from keras.layers import Dense, Activation, Input, Flatten
# from keras import layers
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.mixed_precision import set_global_policy
import numpy as np

set_global_policy("mixed_float16")

import os
import tensorflow as tf
os.environ["OMP_NUM_THREADS"] = str(tf.config.threading.get_inter_op_parallelism_threads())
os.environ["TF_NUM_INTRAOP_THREADS"] = str(tf.config.threading.get_intra_op_parallelism_threads())
num_cores = os.cpu_count()
config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=num_cores, inter_op_parallelism_threads=num_cores)
session = tf.compat.v1.Session(config=config)
from tensorflow.python.keras import backend as K
K.set_session(session)


class ReplayBuffer(object):
  def __init__(self, max_size, input_shape, n_actions, discrete=False):
    self.mem_size = max_size
    self.discrete = discrete
    self.mem_cntr = 0
    self.state_memory = np.zeros((self.mem_size, *input_shape))
    self.new_state_memory = np.zeros((self.mem_size, *input_shape))
    self.action_memory = np.zeros((self.mem_size, n_actions), dtype=np.int8 if self.discrete else np.float32)
    self.reward_memory = np.zeros(self.mem_size)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_cntr % self.mem_size
    # Ensure state and state_ are 2D arrays
    self.state_memory[index] = np.array(state).reshape(*self.state_memory.shape[1:])
    self.new_state_memory[index] = np.array(state_).reshape(*self.new_state_memory.shape[1:])
    self.reward_memory[index] = reward
    self.terminal_memory[index] = 1 - int(done)
    if self.discrete:
      actions = np.zeros(self.action_memory.shape[1])
      actions[action] = 1.0
      self.action_memory[index] = actions
    else:
      self.action_memory[index] = action
    self.mem_cntr += 1

  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_cntr, self.mem_size)
    batch = np.random.choice(max_mem, batch_size)
    return self.state_memory[batch], self.action_memory[batch], self.reward_memory[batch], self.new_state_memory[batch], self.terminal_memory[batch]

def build_dqn(learning_rate, n_actions, input_dims, fc1_dims, fc2_dims):
  model = Sequential([
      Input(shape=input_dims),
      Flatten(),
      Dense(fc1_dims),
      Activation('relu'),
      Dense(fc2_dims),
      Activation('relu'),
      Dense(n_actions)
  ])
  model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
  return model

def set_seeds(seed=100):
  ''' Function to set seeds for all
      random number generators.
  '''
  import tensorflow as tf
  import random
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)

class Agent(object):
  def __init__(self, alpha, gamma, n_actions, epsilon, input_dims, batch_size=72, epsilon_dec=0.9999, epsilon_end=0.01, mem_size=1_000_000, fname='models/8_fin_model.keras'):
    self.action_space = [i for i in range(n_actions)]
    self.n_actions = n_actions
    self.gamma = gamma
    self.epsilon = epsilon
    self.epsilon_dec = epsilon_dec
    self.epsilon_min = epsilon_end
    self.batch_size = batch_size
    self.model_file = fname

    self.memory = ReplayBuffer(mem_size, input_dims, n_actions, discrete=True)
    self.q_eval = build_dqn(alpha, n_actions, input_dims, 128, 128)

  def remember(self, state, action, reward, new_state, done):
    self.memory.store_transition(state, action, reward, new_state, done)

  def choose_optimal_action(self, state):
    return np.argmax(self.q_eval.predict(state[np.newaxis, :], verbose=False))

  def choose_action(self, state):
    action = np.random.choice(self.action_space) if np.random.random() < self.epsilon else self.choose_optimal_action(state)
    return action 

  def learn(self):
    if self.memory.mem_cntr > self.batch_size:
      state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size) # Sample non-sequential memories
      action_values = np.array(self.action_space, dtype=np.int8)
      action_indices = np.dot(action, action_values)
      q_next = self.q_eval.predict(new_state, verbose=False)
      q_eval = self.q_eval.predict(state, verbose=False)
      q_target = q_eval.copy()
      batch_index = np.arange(self.batch_size, dtype=np.int32)
      q_target[batch_index, action_indices] = reward + self.gamma * np.max(q_next, axis=1) * done
      _ = self.q_eval.fit(state, q_target, verbose=False)
      self.epsilon = self.epsilon * self.epsilon_dec if self.epsilon > self.epsilon_min else self.epsilon

  def save_model(self):
    self.q_eval.save(self.model_file)

  def load_model(self):
    self.q_eval = load_model(self.model_file)
    
set_seeds(100)
# Out:
# 2024-07-05 15:49:13.848708: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Validation function that helps test if the agent is learning to generalize or just learning the training data

def validate(agent):
  print("Validating agent", end="", flush=True)
  state = valid_env.reset()
  score = 0
  done = False
  while not done:
    action = agent.choose_optimal_action(state)
    next_state, reward, done, info = valid_env.step(action)
    state = next_state
    score += reward
  print(f"\rValidating agent - Score: {score:.2f}", flush=True)
  return score

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

class LivePlot:
    def __init__(self, ax, xlabel, ylabel, color, label):
        self.ax = ax
        self.line, = self.ax.plot([], [], color, label=label)
        self.ax.set_xlabel(xlabel)
        self.ax.set_ylabel(ylabel)
        self.ax.legend()
        self.x_data = []
        self.y_data = []

    def update(self, new_x, new_y):
        self.x_data.append(new_x)
        self.y_data.append(new_y)
        self.line.set_data(self.x_data, self.y_data)
        self.ax.relim()
        self.ax.autoscale_view()

class RegressionPlot(LivePlot):
    def __init__(self, ax, xlabel, ylabel, color, label):
        super().__init__(ax, xlabel, ylabel, color, label)

    def update(self, new_x, new_y):
        super().update(new_x, new_y)
        if len(self.x_data) > 3:
          y = np.polyval(np.polyfit(self.x_data, self.y_data, deg=3), self.x_data)
          self.line.set_data(self.x_data, y)

# %%
# Only run this cell if you want to re-load an existing model
agent = Agent(gamma=0.99, epsilon=1.0, alpha=0.0005, input_dims=(learn_env.lags, learn_env.n_features), n_actions=learn_env.action_space.n, mem_size=int(1e6), batch_size=64, epsilon_end=0.04, fname='../models/8_fin_model.keras')
agent.load_model()

# %% [markdown]
# # Training the Agent
#
# The cells below demonstrate training the agent on our training set (`train_env`) and monitoring its performance on the validation set (via the `validate` function). Finally to check the performance of the agent on unseen data we evaluate its performance on the `test_env`.

# %%
validation_period = 5
for i in range(n_episodes):
  start_time = time.time() 

  observation, score, done = env.reset(), 0, False
  iteration = 0
  num_long, num_short = 0, 0
  while not done:
    action = agent.choose_action(observation)
    if action == 0:
      num_short += 1
    elif action == 1:
      num_long += 1
    observation_, reward, done, info = env.step(action)
    score += reward
    agent.remember(observation, action, reward, observation_, int(done))
    observation = observation_
    agent.learn()
    if iteration % 100 == 0:
      print("\rFinished Learning iteration: {}".format(iteration), end="")
    iteration += 1

  end_time = time.time()  

  # Bookkeeping
  scores.append(score)
  moving_average = np.mean(scores[-25:])
  moving_average_plot.update(len(moving_average_plot.y_data), moving_average)
  regression_plot.update(len(regression_plot.y_data), moving_average)
  training_logs.append(f'\rEpisode: {len(moving_average_plot.y_data)}, score: {score:.0f}, moving average: {moving_average:.0f}, epsilon: {agent.epsilon:.2g}, long ratio: {100*num_long/(num_long+num_short):.1f}%, time: {end_time - start_time:.2f}')

  
  if i % 10 == 0:
    agent.save_model()
  if i % validation_period == 0:
    # Validation
    score = validate(agent)
    validation_score_plot.update(validation_period*len(validation_score_plot.y_data), score)
    validation_regression_plot.update(validation_period*len(validation_regression_plot.y_data), score)

  # Update plots and logs
  clear_output(wait=True) 
  display(fig)
  [print(log, flush=True) for log in training_logs]
  
# The validation dataset has 1395 rows. 
# So getting 50% correct with 1 point each would give a score of ~700
# Out:
# Episode: 0, score: 1464, moving average: 1464, epsilon: 0.76, long ratio: 48.2%, time: 500.45
# Episode: 1, score: 7, moving average: 736, epsilon: 0.75, long ratio: 66.7%, time: 3.22
# Episode: 2, score: 1413, moving average: 961, epsilon: 0.57, long ratio: 46.8%, time: 532.75
# Episode: 3, score: 1476, moving average: 1090, epsilon: 0.43, long ratio: 46.2%, time: 552.84
# Episode: 4, score: 10, moving average: 874, epsilon: 0.42, long ratio: 46.2%, time: 4.84
# Episode: 5, score: 1561, moving average: 988, epsilon: 0.32, long ratio: 43.6%, time: 566.76
# Episode: 6, score: 9, moving average: 848, epsilon: 0.32, long ratio: 34.8%, time: 4.87
# Episode: 7, score: 9, moving average: 744, epsilon: 0.32, long ratio: 26.1%, time: 4.53
# Episode: 8, score: 1538, moving average: 832, epsilon: 0.24, long ratio: 44.1%, time: 584.07
# Episode: 9, score: 1571, moving average: 906, epsilon: 0.18, long ratio: 43.5%, time: 598.40
# Episode: 10, score: 1591, moving average: 968, epsilon: 0.13, long ratio: 40.9%, time: 605.37
# Episode: 11, score: 1616, moving average: 1022, epsilon: 0.1, long ratio: 43.3%, time: 614.11
# Episode: 12, score: 1661, moving average: 1071, epsilon: 0.076, long ratio: 41.1%, time: 619.87
# Episode: 13, score: 1622, moving average: 1111, epsilon: 0.057, long ratio: 41.7%, time: 625.90
# Episode: 14, score: 1647, moving average: 1146, epsilon: 0.043, long ratio: 42.3%, time: 627.56
# Episode: 15, score: 1655, moving average: 1178, epsilon: 0.04, long ratio: 42.7%, time: 630.05
# Episode: 16, score: 1708, moving average: 1209, epsilon: 0.04, long ratio: 38.5%, time: 634.99
# Episode: 17, score: 1663, moving average: 1235, epsilon: 0.04, long ratio: 41.7%, time: 633.19
# Episode: 18, score: 1708, moving average: 1259, epsilon: 0.04, long ratio: 42.2%, time: 631.82
# Episode: 19, score: 1717, moving average: 1282, epsilon: 0.04, long ratio: 42.8%, time: 632.60
# Episode: 20, score: 1696, moving average: 1302, epsilon: 0.04, long ratio: 41.8%, time: 636.29
# Episode: 21, score: 1753, moving average: 1323, epsilon: 0.04, long ratio: 37.9%, time: 636.07
# Episode: 22, score: 1711, moving average: 1339, epsilon: 0.04, long ratio: 41.6%, time: 633.19
# Episode: 23, score: 1697, moving average: 1354, epsilon: 0.04, long ratio: 44.1%, time: 635.86
# Episode: 24, score: 1750, moving average: 1370, epsilon: 0.04, long ratio: 42.1%, time: 637.09
# Episode: 25, score: 1802, moving average: 1384, epsilon: 0.04, long ratio: 40.8%, time: 632.37
# Episode: 26, score: 1768, moving average: 1454, epsilon: 0.04, long ratio: 39.8%, time: 636.41
# Episode: 27, score: 1798, moving average: 1470, epsilon: 0.04, long ratio: 40.0%, time: 639.36
# Episode: 28, score: 1811, moving average: 1483, epsilon: 0.04, long ratio: 41.8%, time: 637.81
# Episode: 29, score: 1807, moving average: 1555, epsilon: 0.04, long ratio: 39.6%, time: 644.96
# Episode: 0, score: 1857, moving average: 1567, epsilon: 0.04, long ratio: 41.5%, time: 637.71
# Episode: 32, score: 1798, moving average: 1638, epsilon: 0.04, long ratio: 42.1%, time: 648.01
# Episode: 33, score: 1845, moving average: 1712, epsilon: 0.04, long ratio: 41.4%, time: 651.89
# Episode: 34, score: 1863, moving average: 1725, epsilon: 0.04, long ratio: 43.1%, time: 654.85
# Episode: 35, score: 1845, moving average: 1736, epsilon: 0.04, long ratio: 41.1%, time: 656.80
# Episode: 36, score: 1844, moving average: 1746, epsilon: 0.04, long ratio: 42.4%, time: 658.23
# Episode: 37, score: 1833, moving average: 1754, epsilon: 0.04, long ratio: 41.6%, time: 659.78
# Episode: 38, score: 1834, moving average: 1761, epsilon: 0.04, long ratio: 39.2%, time: 644.15
# Episode: 39, score: 1880, moving average: 1772, epsilon: 0.04, long ratio: 44.2%, time: 645.57
# Episode: 40, score: 1883, moving average: 1781, epsilon: 0.04, long ratio: 43.0%, time: 649.51
# Episode: 41, score: 1883, moving average: 1790, epsilon: 0.04, long ratio: 41.3%, time: 647.86
# Episode: 42, score: 1860, moving average: 1796, epsilon: 0.04, long ratio: 44.8%, time: 649.54
# Episode: 43, score: 1882, moving average: 1805, epsilon: 0.04, long ratio: 41.8%, time: 649.91
# Episode: 44, score: 1804, moving average: 1809, epsilon: 0.04, long ratio: 43.9%, time: 648.99
# Episode: 45, score: 1866, moving average: 1815, epsilon: 0.04, long ratio: 41.7%, time: 650.53
# Episode: 46, score: 1837, moving average: 1821, epsilon: 0.04, long ratio: 39.3%, time: 650.89
# Episode: 47, score: 1855, moving average: 1825, epsilon: 0.04, long ratio: 41.8%, time: 645.51
# Episode: 48, score: 1913, moving average: 1833, epsilon: 0.04, long ratio: 41.4%, time: 647.35
# Episode: 49, score: 1877, moving average: 1840, epsilon: 0.04, long ratio: 41.6%, time: 651.45
# Episode: 50, score: 1935, moving average: 1847, epsilon: 0.04, long ratio: 43.7%, time: 651.09
# Episode: 51, score: 1906, moving average: 1851, epsilon: 0.04, long ratio: 45.3%, time: 651.88
# Episode: 52, score: 1900, moving average: 1857, epsilon: 0.04, long ratio: 41.8%, time: 653.64
# Episode: 53, score: 1926, moving average: 1862, epsilon: 0.04, long ratio: 41.7%, time: 654.39
# Episode: 54, score: 1927, moving average: 1866, epsilon: 0.04, long ratio: 42.4%, time: 652.85
# Episode: 55, score: 1910, moving average: 1871, epsilon: 0.04, long ratio: 42.5%, time: 651.12
# Episode: 56, score: 1939, moving average: 1874, epsilon: 0.04, long ratio: 42.0%, time: 655.59
# Episode: 57, score: 1957, moving average: 1880, epsilon: 0.04, long ratio: 41.9%, time: 650.13
# Episode: 58, score: 1939, moving average: 1884, epsilon: 0.04, long ratio: 41.7%, time: 653.28
# Episode: 59, score: 1917, moving average: 1886, epsilon: 0.04, long ratio: 42.1%, time: 653.29
# Episode: 60, score: 1952, moving average: 1890, epsilon: 0.04, long ratio: 43.0%, time: 656.41
# Episode: 61, score: 1927, moving average: 1894, epsilon: 0.04, long ratio: 43.9%, time: 655.79
# Episode: 62, score: 1940, moving average: 1898, epsilon: 0.04, long ratio: 41.8%, time: 640.45
# Episode: 63, score: 1900, moving average: 1901, epsilon: 0.04, long ratio: 43.8%, time: 640.00
# Episode: 64, score: 1945, moving average: 1903, epsilon: 0.04, long ratio: 41.6%, time: 637.84
# Episode: 65, score: 1906, moving average: 1904, epsilon: 0.04, long ratio: 41.5%, time: 640.96
# Episode: 66, score: 1952, moving average: 1907, epsilon: 0.04, long ratio: 44.4%, time: 644.24
# Episode: 67, score: 1947, moving average: 1910, epsilon: 0.04, long ratio: 41.9%, time: 645.18
# Episode: 68, score: 1940, moving average: 1913, epsilon: 0.04, long ratio: 42.1%, time: 641.79
# Episode: 69, score: 1930, moving average: 1918, epsilon: 0.04, long ratio: 43.5%, time: 637.59
# Episode: 70, score: 1954, moving average: 1921, epsilon: 0.04, long ratio: 42.6%, time: 639.75
# Episode: 71, score: 1923, moving average: 1925, epsilon: 0.04, long ratio: 42.2%, time: 640.57
# Episode: 72, score: 1948, moving average: 1928, epsilon: 0.04, long ratio: 43.4%, time: 645.21
# Episode: 73, score: 1982, moving average: 1931, epsilon: 0.04, long ratio: 42.8%, time: 645.30
# Episode: 74, score: 1965, moving average: 1935, epsilon: 0.04, long ratio: 41.3%, time: 646.51
# Episode: 75, score: 1943, moving average: 1935, epsilon: 0.04, long ratio: 43.4%, time: 649.43
# Episode: 76, score: 1982, moving average: 1938, epsilon: 0.04, long ratio: 42.2%, time: 648.28
# Episode: 77, score: 1987, moving average: 1942, epsilon: 0.04, long ratio: 43.1%, time: 650.00
# Episode: 78, score: 1981, moving average: 1944, epsilon: 0.04, long ratio: 43.0%, time: 648.43
# Episode: 79, score: 2002, moving average: 1947, epsilon: 0.04, long ratio: 42.8%, time: 638.42
# Episode: 80, score: 2024, moving average: 1951, epsilon: 0.04, long ratio: 43.0%, time: 639.30
# Episode: 81, score: 1986, moving average: 1953, epsilon: 0.04, long ratio: 43.2%, time: 639.29
# Episode: 82, score: 1999, moving average: 1955, epsilon: 0.04, long ratio: 41.9%, time: 643.37
# Episode: 83, score: 2049, moving average: 1959, epsilon: 0.04, long ratio: 44.8%, time: 642.06
# Episode: 84, score: 2040, moving average: 1964, epsilon: 0.04, long ratio: 43.4%, time: 644.07
# Episode: 85, score: 2029, moving average: 1967, epsilon: 0.04, long ratio: 41.7%, time: 645.81
# Episode: 86, score: 2028, moving average: 1971, epsilon: 0.04, long ratio: 43.0%, time: 645.69
# Episode: 87, score: 2038, moving average: 1975, epsilon: 0.04, long ratio: 44.4%, time: 647.78
# Episode: 88, score: 2058, moving average: 1982, epsilon: 0.04, long ratio: 41.4%, time: 644.79
# Episode: 89, score: 2035, moving average: 1985, epsilon: 0.04, long ratio: 45.5%, time: 644.10
# Episode: 90, score: 2056, moving average: 1991, epsilon: 0.04, long ratio: 44.3%, time: 647.62
# Episode: 91, score: 2021, moving average: 1994, epsilon: 0.04, long ratio: 43.8%, time: 645.26

# %% [markdown]
# Next we'll test the agent on our test set.

# %%
test_env.reset()

test_scores = []
test_averages = []

observation, score, done = test_env.reset(), 0, False
while not done:
  action = agent.choose_optimal_action(observation)
  observation_, reward, done, info = test_env.step(action)
  score += reward
  observation = observation_
print("")
test_scores.append(score)
test_averages.append(np.mean(test_scores[-25:]))


print(f'score: {score:.2f}, moving average: {test_averages[-1]:.2f}')
# Out:
# score: 749.65, moving average: 749.65

# %%
len(test_env.data), len(test_env.data)/2
# Out:
# (1430, 715.0)

# %% [markdown]
# ## Backesting

# %%
import numpy as np
import pandas as pd
pd.set_option('mode.chained_assignment', None)

def backtest(agent, env):
  done = False
  env.data['p'] = 0
  state = env.reset()
  while not done:
    action = np.argmax(agent.q_eval.predict(state[np.newaxis, :], verbose=False))
    position = 1 if action == 1 else -1
    env.data.iloc[env.bar]['p'] = position
    state, reward, done, info = env.step(action)
  env.data['s'] = env.data['p'] * env.data['r']

# %%
backtest(agent, test_env)

# %% [markdown]
# The command below displays the number of short-positions (p=-1) entered vs. the number of long positions entered (p=+1).

# %%
test_env.data['p'].iloc[test_env.lags:].value_counts()
# Out:
# p
#  0    1424
# -1    715
#  1     709
# Name: count, dtype: int64

# %% [markdown]
# So we see that the agent goes short roughly half of the time and long the other half of the time.
#
# The line below evaluates the number of trades.

# %%
sum(test_env.data['p'].iloc[test_env.lags:].diff() != 0)
# Out:
# 227

# %%
(test_env.data[['r', 's']].iloc[test_env.lags:] * test_env.leverage).sum().apply(np.exp) - 1
# Out:
# r    0.01827
# s   -0.11631
# dtype: float64

# %%
(test_env.data[['r', 's']].iloc[test_env.lags:] * test_env.leverage).cumsum().apply(np.exp).plot(figsize=(10, 6));

# %% [markdown]
# # Deployment
#
# One of the most important aspects of the "deployed" version of our "bot", is that it must take actions in response to the streamed data. To achieve this we create a class that inherits from `tpqoa`, and overwrites the `on_success` method, which gets triggered every time a new item of streamed data is received.

# %%
import json
import tpqoa
from datetime import datetime, timedelta
import random
from typing import Optional, Literal, TypedDict
from datetime import datetime, timedelta
import pytz

class LimitOrder(TypedDict):
    id: Optional[int]
    state: Optional[Literal["PENDING", "FILLED", "CANCELLED"]]

class OandaTradingBot(tpqoa.tpqoa) :
  def __init__(self, config_file, agent, granularity, units, verbose=True, init_pl=0.0):
    super(OandaTradingBot, self).__init__(config_file)
    self.init_pl = init_pl
    self.agent = agent
    self.symbol = symbol
    self.env = learn_env
    self.window = self.env.window
    if granularity is None:
      self.granularity = self.env.granularity
    else:
      self.granularity = granularity
    self.units = units
    self.trades = 0
    self.position = 0
    # Get historical data so we can build the features like moving averages
    try:
      end_time = datetime.now(pytz.utc)
      start_time = end_time - timedelta(hours=4)
      start = start_time.strftime('%Y-%m-%d %H:%M:%S')
      end = end_time.strftime('%Y-%m-%d %H:%M:%S')
      print(f"Getting historical data from {start} to {end}")
      mid = api.get_history(instrument='EUR_USD', start=start, end=end, granularity='M1', price='M')
      bid = api.get_history(instrument='EUR_USD', start=start, end=end, granularity='M1', price='B') 
      ask = api.get_history(instrument='EUR_USD', start=start, end=end, granularity='M1', price='A')
      mid.index = mid.index.tz_localize('UTC')
      bid.index = bid.index.tz_localize('UTC')
      ask.index = ask.index.tz_localize('UTC')
      self.tick_data = pd.DataFrame({ 'bid': bid['c'], 'mid': mid['c'], 'ask': ask['c'] }, index=bid.index)
      self._resample_data()
      self.min_length = max(len(self.data),self.env.window + self.env.lags)
    except:
      self.tick_data = pd.DataFrame()
      self.min_length = (self.env.window + self.env.lags)
    self.pl = list()
    self.previous_net_pl = 0.0
    self.verbose = verbose
    self.count = 0
    self.trading_logs = []
    self.limit_order: LimitOrder = {
      "id": None,
      "state": None
    } 

  def _prepare_data(self):
    self.data['r'] = np.log(self.data / self.data.shift(1))
    self.data.dropna(inplace=True)
    self.data['s'] = self.data[self.symbol].rolling(self.window).mean()
    self.data['m'] = self.data['r'].rolling(self.window).mean()
    self.data['v'] = self.data['r'].rolling(self.window).std()
    self.data.dropna(inplace=True)
    # Normalize the data
    self.data_ = (self.data - self.env.mu) / self.env.std

  def _resample_data(self):
    self.data = self.tick_data.resample(self.granularity, label='right').last().ffill().iloc[:-1]
    self.data = pd.DataFrame(self.data['mid'])
    self.data.columns = [self.symbol,]
    self.data.index = self.data.index.tz_localize(None)

  def _get_state(self):
    state = self.data_[self.env.features].iloc[-self.env.lags:]
    return np.reshape(state.values, [1, self.env.lags, self.env.n_features])
  
  def report_trade(self, time, side, order, price):
    if order['type'] == 'LIMIT_ORDER_REJECT':
      print(order)
    else:
      self.trades += 1
      net_pl = float(self.get_account_summary()['pl']) - self.init_pl
      pl = net_pl - self.previous_net_pl
      self.pl.append(pl)
      self.trading_logs.append(f'{time} | *** GOING {side} ({self.trades}) *** | PROFIT/LOSS={pl:.2f} | Cumulative={net_pl:.2f} | Order Price: {price}')
      self.previous_net_pl = net_pl
      if self.verbose:
        pprint(order)
        print(80 * '=')

  def cancel_limit_order(self):
    response =  self.cancel_order(self.limit_order['id'])
    if 'orderCancelRejectTransaction' in response:
      print("cancel_limit_order_response", response)
      if response['orderCancelRejectTransaction']['rejectReason'] == 'ORDER_DOESNT_EXIST':
        # If the order doesn't exist, then it was either filled or cancelled and the update wasn't yet picked up
        self.update_limit_order_state()
        if self.limit_order['state'] == "FILLED":
          self.create_order(self.symbol, units=-self.position * self.units, suppress=True, ret=True)
        elif self.limit_order['state'] == "CANCELLED":
          self.limit_order = { "id": None, "state": None }
    else:
      self.limit_order = { "id": None, "state": None }
      

  def update_limit_order_state(self):
    if self.limit_order['state'] == "PENDING":
      response = json.loads(self.ctx.order.get(self.account_id,self.limit_order['id']).raw_body)
      if 'errorCode' in response:
        # print("update_limit_order_state", response, self.limit_order)
        if response['errorCode'] == 'NO_SUCH_ORDER':
          # Check if any of the most recent transactions corresponds to this order. 
          # If one does, then the order has been filled.
          for t in self.get_transactions(tid=int(response['lastTransactionID'])-3):
            if t.get('id') == str(self.limit_order['id']):
              print(f"Limit order {self.limit_order['id']} filled")
              # t['type'] == 'ORDER_FILL'
              self.limit_order['state'] = "FILLED"
              break
            else:
              pass
        else:
          print("errorCode was not 'NO_SUCH_ORDER'",f"{response['errorCode']=}")
      elif 'order' in response:
        print(f"{response['order']=}")
        if response['order']['state'] == 'PENDING':
          pass
        elif response['order']['state'] == 'CANCELLED':
          print(f"Limit order {self.limit_order['id']} cancelled")
          self.limit_order['state'] = "CANCELLED"
        elif response['order']['state'] == 'FILLED':
          print(f"Limit order {self.limit_order['id']} filled")
          self.limit_order['state'] = "FILLED"
      else:
        print("Neither 'errorCode' nor 'order' in response:", json.dumps(response))

  def on_success (self, time, bid, ask):
    self.count += 1
    new_row = pd.DataFrame({'ask': ask, 'bid': bid, 'mid': (bid + ask) / 2}, index=[pd.Timestamp(time)])
    self.tick_data = pd.concat([self.tick_data, new_row])
    self._resample_data()
    condition = len(self.data) > self.min_length
    print(f"\rcount: {self.count}, ticks: {len(self.data)}, min_length: {self.min_length}", end='\n' if condition else '', flush=True)
    if condition:
      self.min_length += 1
      self._prepare_data ()
      state = self._get_state()[0]
      prediction = self.agent.choose_optimal_action(state)
      print(f'{datetime.fromisoformat(time[:26]).strftime("%H:%M")} | PREDICTION={prediction}')
      signal = 1 if prediction == 1 else -1
      # signal = 1 if random.random() <= 0.1 else -1
      if self.position in [0, -1] and signal == 1:
        price=f"{float(new_row['ask'].iloc[0]):.5f}"
        order = self.create_order(self.symbol, units=self.units, price=price, suppress=True, ret=True)
        print("Order state", self.limit_order['state'])
        if self.limit_order['state'] == "FILLED":
          # Create a market order to immediatley close the position
          self.create_order(self.symbol, units=-self.position * self.units, suppress=True, ret=True)
        elif self.limit_order['state'] == "PENDING":
          self.cancel_limit_order()
        self.limit_order = {
          "id": int(order['id']),
          "state": "PENDING",
        }
        print("new limit order", self.limit_order)
        # order = self.create_order(self.symbol, units=(1 - self.position) * self.units, suppress=True, ret=True)
        self.report_trade(time, 'LONG', order, price),  
        self.position = 1
        print(self.trading_logs[-1], flush=True)
      elif self.position in [0, 1] and signal == -1:
        price=f"{float(new_row['bid'].iloc[0]):.5f}"
        order = self.create_order(self.symbol, units=-self.units, price=price, suppress=True, ret=True)
        print("Order state", self.limit_order['state'])
        if self.limit_order['state'] == "FILLED":
          # Create a market order to immediatley close the position
          self.create_order(self.symbol, units=-self.position * self.units, suppress=True, ret=True)
        elif self.limit_order['state'] == "PENDING":
          self.cancel_limit_order()
        self.limit_order = {
          "id": int(order['id']),
          "state": "PENDING",
        }
        print("new limit order", self.limit_order)
        self.report_trade(time, 'SHORT', order, price)
        self.position = -1
        print(self.trading_logs[-1], flush=True)
    else:
      self.update_limit_order_state()

# %%
import time
import v20

# Set to True if initializing a new bot
if True:
  otb = OandaTradingBot('../oanda.cfg', agent, '5min', 25000, verbose=False, init_pl=float(api.get_account_summary()['pl']))


start = time.time()
while True:
  # stream is run in a while loop so that it is resilient to timeout errors
  if time.time() < start + 24 * 60 * 60:
    try:
      otb.stream_data(symbol, stop=40)
    except v20.errors.V20ConnectionError as e:
      print(f"Stream timeout")
  else:
    break 


print('\n' + 80 * '=')
if otb.position * otb.units != 0:
  print('*** CLOSING OUT ***')
  print(otb.symbol, -otb.position * otb.units)
  price = float(otb.tick_data['ask'].iloc[-1])
  order = otb.create_order(otb.symbol, units=-otb.position * otb.units, price=price, suppress=True, ret=True)
  otb.report_trade(otb.tick_data.index[-1], 'NEUTRAL', order, price)
  if otb.verbose:
    pprint(order)
  print(80 * '=')
# Out:
# Getting historical data from 2024-07-01 11:11:03 to 2024-07-01 15:11:03
# count: 320, ticks: 49, min_length: 48
# 15:15 | PREDICTION=1
# Order state None
# new limit order {'id': 2220, 'state': 'PENDING'}
# 2024-07-01T15:15:01.332628064Z | *** GOING LONG (1) *** | PROFIT/LOSS=0.00 | Cumulative=0.00 | Order Price: 1.07236
# count: 321, ticks: 49, min_length: 49Limit order 2220 filled
# 15:25 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2222, 'state': 'PENDING'}
# 2024-07-01T15:25:00.075692687Z | *** GOING SHORT (2) *** | PROFIT/LOSS=-1.79 | Cumulative=-1.79 | Order Price: 1.07227
# count: 977, ticks: 51, min_length: 51Limit order 2222 filled
# count: 1241, ticks: 52, min_length: 51
# 15:30 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2226, 'state': 'PENDING'}
# 2024-07-01T15:30:00.061765690Z | *** GOING LONG (3) *** | PROFIT/LOSS=0.40 | Cumulative=-1.39 | Order Price: 1.07229
# count: 1242, ticks: 52, min_length: 52Limit order 2226 filled
# count: 1946, ticks: 55, min_length: 54
# 15:45 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2230, 'state': 'PENDING'}
# 2024-07-01T15:45:00.303901507Z | *** GOING SHORT (4) *** | PROFIT/LOSS=-1.59 | Cumulative=-2.98 | Order Price: 1.07220
# count: 1947, ticks: 55, min_length: 55Limit order 2230 filled
# count: 2181, ticks: 56, min_length: 55
# 15:50 | PREDICTION=0
# count: 2422, ticks: 57, min_length: 56
# 15:55 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2234, 'state': 'PENDING'}
# 2024-07-01T15:55:03.151961572Z | *** GOING LONG (5) *** | PROFIT/LOSS=-6.76 | Cumulative=-9.74 | Order Price: 1.07257
# count: 2423, ticks: 57, min_length: 57Limit order 2234 filled
# count: 2611, ticks: 58, min_length: 57
# 16:00 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2238, 'state': 'PENDING'}
# 2024-07-01T16:00:00.692113385Z | *** GOING SHORT (6) *** | PROFIT/LOSS=-2.75 | Cumulative=-12.49 | Order Price: 1.07269
# count: 2612, ticks: 58, min_length: 58Limit order 2238 filled
# count: 3161, ticks: 61, min_length: 60
# 16:15 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2242, 'state': 'PENDING'}
# 2024-07-01T16:15:00.223913140Z | *** GOING LONG (7) *** | PROFIT/LOSS=9.73 | Cumulative=-2.76 | Order Price: 1.07318
# count: 3162, ticks: 61, min_length: 61Limit order 2242 filled
# count: 3336, ticks: 62, min_length: 61
# 16:20 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2246, 'state': 'PENDING'}
# 2024-07-01T16:20:01.547001276Z | *** GOING SHORT (8) *** | PROFIT/LOSS=2.78 | Cumulative=0.02 | Order Price: 1.07304
# count: 3337, ticks: 62, min_length: 62Limit order 2246 filled
# count: 3507, ticks: 63, min_length: 62
# 16:25 | PREDICTION=0
# count: 3704, ticks: 64, min_length: 63
# 16:30 | PREDICTION=0
# count: 3910, ticks: 65, min_length: 64
# 16:35 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2249, 'state': 'PENDING'}
# 2024-07-01T16:35:00.061742199Z | *** GOING LONG (9) *** | PROFIT/LOSS=3.18 | Cumulative=3.19 | Order Price: 1.07319
# Limit order 2249 filled
# count: 4111, ticks: 66, min_length: 65
# 16:40 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2253, 'state': 'PENDING'}
# 2024-07-01T16:40:00.148190528Z | *** GOING SHORT (10) *** | PROFIT/LOSS=-2.98 | Cumulative=0.22 | Order Price: 1.07305
# Limit order 2253 filled
# count: 6652, ticks: 83, min_length: 82
# 18:05 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2258, 'state': 'PENDING'}
# 2024-07-01T18:05:05.371824212Z | *** GOING LONG (11) *** | PROFIT/LOSS=4.33 | Cumulative=4.55 | Order Price: 1.07283
# count: 6653, ticks: 83, min_length: 83Limit order 2258 filled
# count: 6807, ticks: 84, min_length: 83
# 18:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2261, 'state': 'PENDING'}
# 2024-07-01T18:10:00.085483756Z | *** GOING SHORT (12) *** | PROFIT/LOSS=-1.59 | Cumulative=2.96 | Order Price: 1.07277
# Limit order 2261 filled
# count: 6941, ticks: 85, min_length: 84
# 18:15 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2265, 'state': 'PENDING'}
# 2024-07-01T18:15:00.200986467Z | *** GOING LONG (13) *** | PROFIT/LOSS=0.59 | Cumulative=3.55 | Order Price: 1.07272
# Limit order 2265 filled
# count: 7075, ticks: 86, min_length: 85
# 18:20 | PREDICTION=1
# count: 7199, ticks: 87, min_length: 86
# 18:25 | PREDICTION=1
# count: 7329, ticks: 88, min_length: 87
# 18:30 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2270, 'state': 'PENDING'}
# 2024-07-01T18:30:00.307570871Z | *** GOING SHORT (14) *** | PROFIT/LOSS=-4.97 | Cumulative=-1.42 | Order Price: 1.07247
# count: 7330, ticks: 88, min_length: 88Limit order 2270 filled
# count: 8278, ticks: 94, min_length: 93
# 19:00 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2274, 'state': 'PENDING'}
# 2024-07-01T19:00:00.546123857Z | *** GOING LONG (15) *** | PROFIT/LOSS=10.53 | Cumulative=9.11 | Order Price: 1.07300
# count: 8279, ticks: 94, min_length: 94Limit order 2274 filled
# count: 8450, ticks: 95, min_length: 94
# 19:05 | PREDICTION=1
# count: 8584, ticks: 96, min_length: 95
# 19:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2278, 'state': 'PENDING'}
# 2024-07-01T19:10:00.745894118Z | *** GOING SHORT (16) *** | PROFIT/LOSS=3.54 | Cumulative=12.65 | Order Price: 1.07318
# count: 8585, ticks: 96, min_length: 96Limit order 2278 filled
# count: 8823, ticks: 97, min_length: 96
# 19:15 | PREDICTION=0
# count: 8982, ticks: 98, min_length: 97
# 19:20 | PREDICTION=0
# count: 9122, ticks: 99, min_length: 98
# 19:25 | PREDICTION=0
# count: 9273, ticks: 100, min_length: 99
# 19:30 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2282, 'state': 'PENDING'}
# 2024-07-01T19:30:00.029701017Z | *** GOING LONG (17) *** | PROFIT/LOSS=-8.35 | Cumulative=4.30 | Order Price: 1.07359
# count: 9274, ticks: 100, min_length: 100Limit order 2282 filled
# count: 9396, ticks: 101, min_length: 100
# 19:35 | PREDICTION=1
# count: 9630, ticks: 102, min_length: 101
# 19:40 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2286, 'state': 'PENDING'}
# 2024-07-01T19:40:00.113958868Z | *** GOING SHORT (18) *** | PROFIT/LOSS=0.79 | Cumulative=5.09 | Order Price: 1.07361
# count: 9631, ticks: 102, min_length: 102Limit order 2286 filled
# count: 9794, ticks: 103, min_length: 102
# 19:45 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2290, 'state': 'PENDING'}
# 2024-07-01T19:45:01.941716081Z | *** GOING LONG (19) *** | PROFIT/LOSS=-2.38 | Cumulative=2.71 | Order Price: 1.07375
# count: 9795, ticks: 103, min_length: 103Limit order 2290 filled
# count: 9939, ticks: 104, min_length: 103
# 19:50 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2294, 'state': 'PENDING'}
# 2024-07-01T19:50:00.136958577Z | *** GOING SHORT (20) *** | PROFIT/LOSS=0.20 | Cumulative=2.90 | Order Price: 1.07376
# count: 9940, ticks: 104, min_length: 104Limit order 2294 filled
# count: 10066, ticks: 105, min_length: 104
# 19:55 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2298, 'state': 'PENDING'}
# 2024-07-01T19:55:00.132913141Z | *** GOING LONG (21) *** | PROFIT/LOSS=-1.39 | Cumulative=1.51 | Order Price: 1.07383
# count: 10067, ticks: 105, min_length: 105Limit order 2298 filled
# count: 10567, ticks: 111, min_length: 110
# 20:25 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2302, 'state': 'PENDING'}
# 2024-07-01T20:25:58.755659591Z | *** GOING SHORT (22) *** | PROFIT/LOSS=4.52 | Cumulative=6.04 | Order Price: 1.07406
# count: 10568, ticks: 111, min_length: 111Limit order 2302 filled
# count: 10619, ticks: 112, min_length: 111
# 20:30 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2306, 'state': 'PENDING'}
# 2024-07-01T20:30:32.557274141Z | *** GOING LONG (23) *** | PROFIT/LOSS=-1.79 | Cumulative=4.25 | Order Price: 1.07416
# count: 10620, ticks: 112, min_length: 112Limit order 2306 filled
# count: 10675, ticks: 113, min_length: 112
# 20:35 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2310, 'state': 'PENDING'}
# 2024-07-01T20:35:00.073023748Z | *** GOING SHORT (24) *** | PROFIT/LOSS=1.38 | Cumulative=5.62 | Order Price: 1.07422
# count: 10676, ticks: 113, min_length: 113Limit order 2310 filled
# count: 10765, ticks: 114, min_length: 113
# 20:40 | PREDICTION=0
# count: 10802, ticks: 115, min_length: 114
# 20:45 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2314, 'state': 'PENDING'}
# 2024-07-01T20:45:00.332691032Z | *** GOING LONG (25) *** | PROFIT/LOSS=2.95 | Cumulative=8.57 | Order Price: 1.07407
# count: 10803, ticks: 115, min_length: 115Limit order 2314 filled
# count: 10850, ticks: 116, min_length: 115
# 20:50 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2318, 'state': 'PENDING'}
# 2024-07-01T20:50:00.063758566Z | *** GOING SHORT (26) *** | PROFIT/LOSS=-0.79 | Cumulative=7.78 | Order Price: 1.07401
# count: 10851, ticks: 116, min_length: 116Limit order 2318 filled
# count: 10946, ticks: 119, min_length: 118
# 21:05 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2323, 'state': 'PENDING'}
# 2024-07-01T21:05:01.861521948Z | *** GOING LONG (27) *** | PROFIT/LOSS=1.77 | Cumulative=9.55 | Order Price: 1.07392
# count: 10947, ticks: 119, min_length: 119Limit order 2323 filled
# count: 10981, ticks: 120, min_length: 119
# 21:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2326, 'state': 'PENDING'}
# 2024-07-01T21:10:01.889142774Z | *** GOING SHORT (28) *** | PROFIT/LOSS=-5.16 | Cumulative=4.39 | Order Price: 1.07369
# count: 11211, ticks: 126, min_length: 125
# 21:40 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2331, 'state': 'PENDING'}
# 2024-07-01T21:40:12.996273007Z | *** GOING LONG (29) *** | PROFIT/LOSS=7.15 | Cumulative=11.54 | Order Price: 1.07408
# count: 11212, ticks: 126, min_length: 126Limit order 2331 filled
# count: 11279, ticks: 127, min_length: 126
# 21:45 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2335, 'state': 'PENDING'}
# 2024-07-01T21:45:02.842791858Z | *** GOING SHORT (30) *** | PROFIT/LOSS=3.77 | Cumulative=15.31 | Order Price: 1.07389
# count: 11280, ticks: 127, min_length: 127Limit order 2335 filled
# count: 11508, ticks: 131, min_length: 130
# 22:05 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2339, 'state': 'PENDING'}
# 2024-07-01T22:05:00.140732138Z | *** GOING LONG (31) *** | PROFIT/LOSS=0.60 | Cumulative=15.91 | Order Price: 1.07392
# count: 11509, ticks: 131, min_length: 131Limit order 2339 filled
# count: 11538, ticks: 132, min_length: 131
# 22:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2343, 'state': 'PENDING'}
# 2024-07-01T22:10:00.059620631Z | *** GOING SHORT (32) *** | PROFIT/LOSS=-1.19 | Cumulative=14.71 | Order Price: 1.07388
# count: 11539, ticks: 132, min_length: 132Limit order 2343 filled
# 22:50 | PREDICTION=0
# Stream timeout
# count: 11891, ticks: 140, min_length: 140Stream timeout
# 01:05 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2347, 'state': 'PENDING'}
# 2024-07-02T01:05:00.288201129Z | *** GOING LONG (33) *** | PROFIT/LOSS=9.64 | Cumulative=24.36 | Order Price: 1.07339
# count: 14336, ticks: 167, min_length: 167Limit order 2347 filled
# count: 14455, ticks: 168, min_length: 167
# 01:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2351, 'state': 'PENDING'}
# 2024-07-02T01:10:01.388779903Z | *** GOING SHORT (34) *** | PROFIT/LOSS=-0.99 | Cumulative=23.36 | Order Price: 1.07334
# count: 14456, ticks: 168, min_length: 168Limit order 2351 filled
# count: 14770, ticks: 171, min_length: 170
# 01:25 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2355, 'state': 'PENDING'}
# 2024-07-02T01:25:01.336971901Z | *** GOING LONG (35) *** | PROFIT/LOSS=-0.40 | Cumulative=22.97 | Order Price: 1.07336
# count: 14771, ticks: 171, min_length: 171Limit order 2355 filled
# count: 14856, ticks: 172, min_length: 171
# 01:30 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2359, 'state': 'PENDING'}
# 2024-07-02T01:30:00.619046182Z | *** GOING SHORT (36) *** | PROFIT/LOSS=-0.99 | Cumulative=21.97 | Order Price: 1.07331
# count: 14857, ticks: 172, min_length: 172Limit order 2359 filled
# count: 15386, ticks: 177, min_length: 176
# 01:55 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2363, 'state': 'PENDING'}
# 2024-07-02T01:55:00.088347122Z | *** GOING LONG (37) *** | PROFIT/LOSS=4.57 | Cumulative=26.54 | Order Price: 1.07355
# count: 15387, ticks: 177, min_length: 177Limit order 2363 filled
# count: 15482, ticks: 178, min_length: 177
# 02:00 | PREDICTION=1
# count: 15591, ticks: 179, min_length: 178
# 02:05 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2367, 'state': 'PENDING'}
# 2024-07-02T02:05:16.456840626Z | *** GOING SHORT (38) *** | PROFIT/LOSS=-3.18 | Cumulative=23.36 | Order Price: 1.07339
# count: 15592, ticks: 179, min_length: 179Limit order 2367 filled
# count: 16043, ticks: 183, min_length: 182
# 02:25 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2371, 'state': 'PENDING'}
# 2024-07-02T02:25:30.058270600Z | *** GOING LONG (39) *** | PROFIT/LOSS=0.80 | Cumulative=24.16 | Order Price: 1.07343
# count: 16044, ticks: 183, min_length: 183Limit order 2371 filled
# count: 16105, ticks: 184, min_length: 183
# 02:30 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2375, 'state': 'PENDING'}
# 2024-07-02T02:30:00.703897544Z | *** GOING SHORT (40) *** | PROFIT/LOSS=-3.18 | Cumulative=20.98 | Order Price: 1.07327
# count: 16106, ticks: 184, min_length: 184Limit order 2375 filled
# count: 16195, ticks: 185, min_length: 184
# 02:35 | PREDICTION=0
# count: 16297, ticks: 186, min_length: 185
# 02:40 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2379, 'state': 'PENDING'}
# 2024-07-02T02:40:03.398399597Z | *** GOING LONG (41) *** | PROFIT/LOSS=-1.39 | Cumulative=19.59 | Order Price: 1.07334
# count: 16298, ticks: 186, min_length: 186Limit order 2379 filled
# count: 16421, ticks: 187, min_length: 186
# 02:45 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2383, 'state': 'PENDING'}
# 2024-07-02T02:45:00.276174745Z | *** GOING SHORT (42) *** | PROFIT/LOSS=0.39 | Cumulative=19.98 | Order Price: 1.07336
# count: 16422, ticks: 187, min_length: 187Limit order 2383 filled
# count: 16553, ticks: 188, min_length: 187
# 02:50 | PREDICTION=0
# count: 16658, ticks: 189, min_length: 188
# 02:55 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2387, 'state': 'PENDING'}
# 2024-07-02T02:55:08.080330479Z | *** GOING LONG (43) *** | PROFIT/LOSS=-1.59 | Cumulative=18.39 | Order Price: 1.07344
# count: 16659, ticks: 189, min_length: 189Limit order 2387 filled
# count: 16746, ticks: 190, min_length: 189
# 03:00 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2391, 'state': 'PENDING'}
# 2024-07-02T03:00:00.083008781Z | *** GOING SHORT (44) *** | PROFIT/LOSS=0.59 | Cumulative=18.98 | Order Price: 1.07347
# count: 16747, ticks: 190, min_length: 190Limit order 2391 filled
# count: 16811, ticks: 191, min_length: 190
# 03:05 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2395, 'state': 'PENDING'}
# 2024-07-02T03:05:02.686567342Z | *** GOING LONG (45) *** | PROFIT/LOSS=1.39 | Cumulative=20.37 | Order Price: 1.07354
# count: 16812, ticks: 191, min_length: 191Limit order 2395 filled
# count: 16894, ticks: 192, min_length: 191
# 03:10 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2399, 'state': 'PENDING'}
# 2024-07-02T03:10:02.024568263Z | *** GOING SHORT (46) *** | PROFIT/LOSS=-6.96 | Cumulative=13.41 | Order Price: 1.07319
# count: 16895, ticks: 192, min_length: 192Limit order 2399 filled
# 03:25 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2403, 'state': 'PENDING'}
# 2024-07-02T03:25:09.701732613Z | *** GOING LONG (47) *** | PROFIT/LOSS=3.78 | Cumulative=17.19 | Order Price: 1.07338
# count: 17192, ticks: 195, min_length: 195Limit order 2403 filled
# count: 17260, ticks: 196, min_length: 195
# 03:30 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2407, 'state': 'PENDING'}
# 2024-07-02T03:30:00.609050211Z | *** GOING SHORT (48) *** | PROFIT/LOSS=4.57 | Cumulative=21.76 | Order Price: 1.07315
# count: 17261, ticks: 196, min_length: 196Limit order 2407 filled
# count: 17555, ticks: 200, min_length: 199
# 03:50 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2411, 'state': 'PENDING'}
# 2024-07-02T03:50:08.004362773Z | *** GOING LONG (49) *** | PROFIT/LOSS=-0.60 | Cumulative=21.17 | Order Price: 1.07318
# count: 17556, ticks: 200, min_length: 200Limit order 2411 filled
# count: 17647, ticks: 201, min_length: 200
# 03:55 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2415, 'state': 'PENDING'}
# 2024-07-02T03:55:10.533510527Z | *** GOING SHORT (50) *** | PROFIT/LOSS=0.39 | Cumulative=21.56 | Order Price: 1.07320
# count: 17648, ticks: 201, min_length: 201Limit order 2415 filled
# count: 17853, ticks: 204, min_length: 203
# 04:10 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2419, 'state': 'PENDING'}
# 2024-07-02T04:10:02.624087842Z | *** GOING LONG (51) *** | PROFIT/LOSS=-2.39 | Cumulative=17.78 | Order Price: 1.07332
# count: 17854, ticks: 204, min_length: 204Limit order 2419 filled
# count: 17964, ticks: 206, min_length: 205
# 04:20 | PREDICTION=0
# Order state FILLED
# new limit order {'id': 2423, 'state': 'PENDING'}
# 2024-07-02T04:20:02.568441791Z | *** GOING SHORT (52) *** | PROFIT/LOSS=-1.39 | Cumulative=21.33 | Order Price: 1.07325
# count: 17965, ticks: 206, min_length: 206Limit order 2423 filled
# count: 18422, ticks: 211, min_length: 210
# 04:45 | PREDICTION=1
# Order state FILLED
# new limit order {'id': 2426, 'state': 'PENDING'}
# 2024-07-02T04:45:00.187141229Z | *** GOING LONG (53) *** | PROFIT/LOSS=3.54 | Cumulative=17.75 | Order Price: 1.07306
# Limit order 2426 filled
# count: 18545, ticks: 212, min_length: 211
# ================================================================================
# *** CLOSING OUT ***
# EUR_USD 25000
# ================================================================================

# %% [markdown]
# # Performance Analysis

# %%
pl = np.array(otb.pl)

pl
# Out:
# array([ 0.    , -1.7891,  0.3976, -1.5902, -6.7575, -2.7537,  9.7309,
#         2.7796,  3.1773, -2.9789,  4.3304, -1.5905,  0.5906, -4.9712,
#        10.5341,  3.5414, -8.3469,  0.7869, -2.3845,  0.1967, -1.3908,
#         4.5236, -1.7879,  1.3767,  2.9502, -0.7945,  1.7696, -5.1646,
#         7.1512,  3.7742,  0.5959, -1.1919,  9.6435, -0.9938, -0.3976,
#        -0.9941,  4.5717, -3.1804,  0.7951, -3.1806, -1.3916,  0.3936,
#        -1.5906,  0.5905,  1.3917, -6.9603,  3.7783,  4.5742, -0.5966,
#         0.3938, -2.3862, -1.3919,  3.544 , -3.5799])

# %%
pl.cumsum()
# Out:
# array([  0.    ,  -1.7891,  -1.3915,  -2.9817,  -9.7392, -12.4929,
#         -2.762 ,   0.0176,   3.1949,   0.216 ,   4.5464,   2.9559,
#          3.5465,  -1.4247,   9.1094,  12.6508,   4.3039,   5.0908,
#          2.7063,   2.903 ,   1.5122,   6.0358,   4.2479,   5.6246,
#          8.5748,   7.7803,   9.5499,   4.3853,  11.5365,  15.3107,
#         15.9066,  14.7147,  24.3582,  23.3644,  22.9668,  21.9727,
#         26.5444,  23.364 ,  24.1591,  20.9785,  19.5869,  19.9805,
#         18.3899,  18.9804,  20.3721,  13.4118,  17.1901,  21.7643,
#         21.1677,  21.5615,  19.1753,  17.7834,  21.3274,  17.7475])

# %%
# %matplotlib inline
plt.bar(np.arange(1,len(pl)+1 ), pl, color=['g' if p > 0 else 'r' for p in pl])
plt.ylabel("EURUSD P&L")
plt.xlabel("Trade #")
plt.show()

# %%
plt.plot(np.arange(1, len(pl)+1), pl.cumsum())
plt.ylabel("EURUSD P&L")
plt.xlabel("Trades")
# Out:
# Text(0.5, 0, 'Trades')
